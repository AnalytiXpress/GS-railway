# %%
#======================================================================================================

import ipywidgets as w
from IPython.display import display, clear_output, Image, IFrame, HTML
import numpy as np
import pandas as pd
import re, pyperclip
import time

# %%
#======================================================================================================

_grey_font = "<font color = grey>"
_green_font = "<font color = #17a6a6>"
_green_font2 = "<font color = #00b100>"
_red_font = "<font color = #f9768c>"
_blue_font = "<font color = #17b8ee>"
_violet_font = "<font color = #be60fd>"

_bisque_highlight = '<mark style="background-color: bisque">' 
_green_highlight = '<mark style="background-color: #c3eaea">' 
_skyblue_highlight = '<mark style="background-color: #bce7f5">' 
_grey_highlight = '<mark style="background-color: #e0e0e0">' 
_red_highlight = '<mark style="background-color: #eeb4b6">' 
_violet_highlight = '<mark style="background-color: #f4c3f1">' 

_no_highlight = '</mark>'

#======================================================

_main_font_graphessor = '<div style="font-family: Comic Sans MS; font-size: 14px; line-height: 1.4"><b>'

# %%
#======================================================================================================

_dashboard_out = w.Box()

_dashboard_out_main = w.Output(layout=w.Layout(height='730px', width='99.5%',
                                          justify_content='center', align_items='center'))

_dashboard_out_canvas = w.Output(layout=w.Layout(height='730px', width='99.5%',
                                          justify_content='center', align_items='center'))

_style_placeholder_main = w.Output(layout=w.Layout(height='0px'))
_style_placeholder_canvas = w.Output(layout=w.Layout(height='0px'))

# ------------------------------------------

_tab_top = w.Box(layout=w.Layout(height = '45px', overflow='clip',
                                 justify_content='center', align_items='center'))
_tab_body = w.Box(layout=w.Layout(height = '625px', overflow='clip',
                                  justify_content='center', align_items='center',
                                 border_top = '3px solid grey', border_bottom = '3px solid grey'))
_tab_bottom = w.Output(layout=w.Layout(height = '45px'))

_dashboard_title = w.Text(value = 'This is a dashboard', placeholder = 'Enter dashboard title', layout=w.Layout(width = '200px'))
_dashboard_color = w.ColorPicker(value = 'linen')

_view_code = w.Button(description = 'View code', layout=w.Layout(width = '100px'))

# ------------------------------------------

for i in 'Canvas Filters Code'.split():
    
    globals()['_' + i.lower() + '_button'] = w.Button(description = i, 
                                        style = w.ButtonStyle(font_weight = 'bold',
                                                              font_size = '16px'))

# ------------------------------------------

_separator = w.Label('┃', style = {'font_weight': 'bold', 'text_color': 'grey'})

_style_main = f"""
<style>
.style_main {{
    background-color:linen;
    background-image: url('https://dl.dropbox.com/scl/fi/mzqueq3rdstyo5ww6ilie/GS-test2.png?rlkey=voplmjheqdj2lnytpbisu68av&dl=0');
    background-size: 100%;
    background-repeat: repeat; 
    background-position: center; 
    border-radius: 20px; 
    border: 4px solid {'grey'};
}}
</style>
"""

_style_canvas = f"""
<style>
.style_canvas {{
    background-color:linen;
    border-radius: 20px; 
    border: 4px solid {'grey'};
}}
</style>
"""

_dashboard_out_main.add_class("style_main")
_dashboard_out_canvas.add_class("style_canvas")

# ------------------------------------------

with _dashboard_out_main:
    
    display(HTML(_style_main))
    
with _dashboard_out_canvas:
    
    display(HTML(_style_canvas))

# %%
#======================================================================================================

_graphs_top_out = w.Output(layout=w.Layout(width = 'auto', height = 'auto'))

_graphs_bottom_out = w.Output(layout=w.Layout(width = '100%', height = 'auto'))

# ------------------------------------------

_canvas_rows = w.Text(layout = w.Layout(width='70px'), placeholder = 'e.g., 3')
_canvas_cols = w.Text(layout = w.Layout(width='70px'), placeholder = 'e.g., 4')
_create_canvas = w.Button(icon = 'check', layout = w.Layout(width = '35px'))
_canvas_button_colors = ['#F28482',
                         '#84A59D',
                         '#F6BD60',
                         '#F5CAC3',
                         '#93A8AC',
                         '#D7CEB2']*10

# ------------------------------------------

# _graph_types = w.Dropdown(options = 'Scatter Plot, Line Plot, Bar Plot, Pie Plot, Histogram, HeatMap, Table'.split(', '), layout=w.Layout(width = '120px'))

_graph_types = 'Scatter Plot, Line Plot, Bar Plot, Pie Plot, Histogram, HeatMap, Table'.split(', ')


for i in _graph_types:
    
    globals()[i.replace(' ', '_') + '_button'] = w.Button(description = i, layout=w.Layout(width = '150px'),
                                                         style = w.ButtonStyle(font_size = '14px'))
    
    string = \
        'def ' + i.replace(' ', '_') + '_func(a):' + '\n' + \
            '\tglobal _graph_type_selector; _graph_type_selector = "' + i + '"\n' + \
        i.replace(' ', '_') + '_button.on_click(' + i.replace(' ', '_') + '_func)\n'
    
    exec(string)
        

_graph_title = w.Text(value = 'Scatter Plot', placeholder = 'Enter graph title', layout=w.Layout(width = '200px'))
_add_graph = w.Button(description = 'Add graph', layout=w.Layout(width = '100px'), disabled=True)

_restart_canvas = w.Button(description = 'Restart', icon = 'refresh', layout=w.Layout(width = '100px'))

#======================================================================================================
    
with _dashboard_out_main:
    
    display(_style_placeholder_main)
    
    display(w.Output(layout=w.Layout(height = '200px')))

    display(w.Label('𝗚𝗥𝗔𝗣𝗛𝗘𝗦𝗦𝗢𝗥', 
                        layout  = w.Layout(align_items='center', justify_content='center', height = '150px'), 
                        style = {'font_size' :'84px','text_color': '#32b7ec', 'font_weight':'bold'}),

                w.HBox([
                    w.Label('create a',
                                style = {'font_size' :'24px', 'font_weight': 'bold', 'text_color': 'grey'}),
                    _canvas_rows, 
                    w.Label(' x ',
                                style = {'font_size' :'24px', 'font_weight': 'bold', 'text_color': 'grey'}),
                    _canvas_cols,
                    w.Label(' canvas',
                                style = {'font_size' :'24px', 'font_weight': 'bold', 'text_color': 'grey'}),
                    _create_canvas],

                layout=w.Layout(align_items='center', justify_content='center', height = '45px')))
    
# ------------------------------------------

_tab_top.children = [_graphs_top_out]
_tab_body.children = [_graphs_bottom_out]

_dashboard_out.children = [_dashboard_out_main]

# %%
#========================================================================================================

def _check_isdigit(a):
    
    global _rows, _columns
    
    if _canvas_rows.value == '' and _canvas_cols.value == '':

        _rows = 3
        _columns = 4

        _create_canvas.on_click(_create_canvas_func)

    elif all([_canvas_rows.value.isdigit(), _canvas_cols.value.isdigit()]):
        
        if int(_canvas_rows.value) < 11 and int(_canvas_cols.value) < 13:

            _rows = int(_canvas_rows.value)
            _columns = int(_canvas_cols.value)

            _create_canvas.on_click(_create_canvas_func)
            
        else:
            
            _canvas_rows.value = ''
            _canvas_cols.value = ''

            _create_canvas.on_click(_create_canvas_func, remove=True)

    else:

        _canvas_rows.value = ''
        _canvas_cols.value = ''

        _create_canvas.on_click(_create_canvas_func, remove=True)    
        
_create_canvas.on_click(_check_isdigit)

#===========================================

def _restart_canvas_func(a):
    
    with _dashboard_out_main:
    
        display(_style_placeholder_main)
        
        display(w.Output(layout=w.Layout(height = '200px')))

        display(w.Label('𝗚𝗥𝗔𝗣𝗛𝗘𝗦𝗦𝗢𝗥', 
                            layout  = w.Layout(align_items='center', justify_content='center', height = '150px'), 
                            style = {'font_size' :'84px','text_color': '#32b7ec', 'font_weight':'bold'}),

                    w.HBox([
                        w.Label('create a',
                                    style = {'font_size' :'24px', 'font_weight': 'bold', 'text_color': 'grey'}),
                        _canvas_rows, 
                        w.Label(' x ',
                                    style = {'font_size' :'24px', 'font_weight': 'bold', 'text_color': 'grey'}),
                        _canvas_cols,
                        w.Label(' canvas',
                                    style = {'font_size' :'24px', 'font_weight': 'bold', 'text_color': 'grey'}),
                        _create_canvas],

                    layout=w.Layout(align_items='center', justify_content='center', height = '45px')))
    
    _canvas_rows.value = ''
    _canvas_cols.value = ''
    
#     _graph_types.value = 'Scatter Plot'
#     _graph_title.value = 'Scatter Plot'
    
    _dashboard_title.value = 'This is a Dashboard'
    _dashboard_color.value = 'linen'
    
    _dashboard_out.children = [_dashboard_out_main]
    
_restart_canvas.on_click(_restart_canvas_func)

# %%
#========================================================================================================

def _show_add_graph(a):
    
    with _graphs_top_out:
        clear_output(True)
        display(w.HBox([
            w.Label('Graph ' + str(_counter + 1),
                        style = {'font_size' :'24px', 'font_weight': 'bold', 'text_color': '#32b7ec'}),
            _separator,
            w.HBox([globals()[i.replace(' ', '_') + '_button'] for i in _graph_types]), 
            _separator,
            _restart_canvas],
            
        layout=w.Layout(align_items='center', justify_content='center', height = '45px')))

# ------------------------------------------

def _create_canvas_func(a):
    
    global _rows, _columns
    
    #---------------------------
    
    # Each time a legitimate area is submitted as a graph, the counter will advance, which will be used for
    # naming the graphs (i.e. Figure 1, Figure 2 etc) and other maintenance reasons
    
    global _counter 
    _counter = 0

    #---------------------------
    
    # dict that will capture modulo for each button, see below
    
    global _modulo_dict
    _modulo_dict = {}
    
    global _graph_titles # list of graph titles
    _graph_titles = []
    
    #---------------------------
    
    global _specs_graphs # list of graph types, ie., [Table, Bar, Scatter] for the final specs
    _specs_graphs = []
    
    global _specs_elements # individual elements of the specs argument for plotly
    _specs_elements = ['' for i in range(_rows*_columns)]

    global _final_specs # final specs argument for plotly based on specs_elements
    _final_specs = ['' for i in  range(_rows)]
    
    #---------------------------
    
    global _row_col_start # list of row/col tuples representing row/col start for each graph
    _row_col_start = []
    
    #----------------------------------------------------------------------------------------------

    # Make and display canvas
    
    width = str(100/int(_columns))
    height = str((600/_rows) - (0.25*(_rows)))

    canvas_children = [] # children for the whole canvas

    start = 1
    end = _columns +1

    for j in range(_rows):
        
        globals()['_canvas_children_' + str(j+1)] = [] # children for each _rows of buttons
        
        for i in range(start, end):

            globals()["_Sel_" + str(i)] = w.Button(layout = w.Layout(
                                            width = width + '%', height = height + 'px'), 
                                            style={'button_color':'gainsboro'})

            globals()['_canvas_children_' + str(j+1)].append(globals()["_Sel_" + str(i)])

        start+= _columns
        end+= _columns

        canvas_children.append(globals()['_canvas_children_' + str(j+1)])

    #---------------------------
    
    # iterate through all the buttons and determine what happens when it is pressed
    # i.e., which other buttons get highlighted and which ones don't
    # this will be determined using _modulo_dict
    # for example, pressing button 4 will highlight buttons 1, 2, 3 and 5, 6, 7 (eg. 3x4 grid)
    
    for i in np.arange(_columns*_rows) + 1:
        
        #---------------------------
        
        # create _modulo_dict
        
        modulo = i%_columns
        
        if modulo == 0:
            modulo = _columns
        
        _modulo_dict[i] = modulo # modulo for each button in the canvas
        
        #---------------------------
        
        # for each button, determine which buttons get highlighted darkgrey
        
        ls = []

        for j in range(1, modulo+1):
            ls.append([i for i in _modulo_dict.keys() if _modulo_dict[i] == j])

        ls = sorted([item for k in ls for item in k])

        # all the other buttons that should not be highlighted
        non_ls = sorted([i for i in list(np.arange(_rows*_columns)+1) if i not in ls])

        # for each button, create function for highlighting relevant buttons

        string = 'global _Sel_' + str(i) + '_func' + '\n'  +   \
                 'def _Sel_' + str(i) + '_func(a):' + '\n' + \
                 '\tglobal _to_commit' + '\n' + \
                 '\t_to_commit = ' + ''.join(str(ls)) + '\n' + \
                 '\tfor k in ' + ''.join(str(ls)) + ':' + '\n' + \
                 '\t\tglobals()["_Sel_" + str(k)].style.button_color = "' + 'darkgrey' + '"\n' + \
                 '\tfor k in ' + ''.join(str(non_ls)) + ':' + '\n' + \
                 '\t\tglobals()["_Sel_" + str(k)].style.button_color = "gainsboro"' + '\n' + \
                 '_Sel_' + str(i) + '.on_click(_Sel_' + str(i) + '_func)' + '\n' + \
                 '_Sel_' + str(i) + '.on_click(_show_add_graph)' 

        exec(string)
    
    #---------------------------
    
    # Show canvas
    
    with _graphs_bottom_out:
        clear_output(True)
        display(w.VBox([w.HBox(i) for i in canvas_children]))
    
    with _graphs_top_out:
        display(w.HBox([
                w.Label('Select an area for a graph to continue',
                            style = {'font_size' :'20px', 'font_weight': 'bold', 'font_family' : 'Chalkduster',
                                     'text_color': '#32b7ec'}),
                _separator, _restart_canvas],
            layout=w.Layout(align_items='center', justify_content='center', height = '45px')))
    

    with _tab_bottom:
        display(w.VBox([w.Output(layout=w.Layout(height = '3px')),
            w.HBox([_canvas_button, _filters_button, _code_button],
                  layout=w.Layout(align_items='center', justify_content='center'))]))
        
    
    _dashboard_out.children = [_dashboard_out_canvas]
    
    with _dashboard_out_canvas:
    
        display(_style_placeholder_canvas)

        display(w.VBox([_tab_top, _tab_body, _tab_bottom]))

# %%
# ========================================================================================================

def _add_graph_func(a):
    
    global _counter, _seq
        
    #---------------------------
    
    # sequence of buttons that should be highlighted
    
    if _counter == 0: # when the very first figure is being made 
        
        _seq = _to_commit # to_commit is determined in create_canvas_func
        
    else: 
        
        # it is possible that some of the buttons that are eligible for coloring and those that are
        # already colored in the previous step overlap. Do not recolor those that are already colored
        
        _seq = [i for i in _to_commit if i not in _colored_buttons] # _colored_buttons is determined in _non_colored_buttons_func
    
    #---------------------------
    
    # when add_graph is pressed, highlight the selected buttons and change their descriptions and assign
    # name for the top left corner button of the selected area, i.e. Fugure 1, Figure 2 etc
    
    for i in _seq:

        string = '_Sel_' + str(i) + ".style.button_color = '" + _canvas_button_colors[_counter] + "'"
        exec(string)
        string = '_Sel_' + str(min(_seq)) + ".description = '" + str(_counter+1) + "'"
        exec(string)
        string = '_Sel_' + str(min(_seq)) + ".style.font_size = 'auto'"
        exec(string)
        string = '_Sel_' + str(min(_seq)) + ".style.font_weight = 'bold'"
        exec(string)
    
    #---------------------------
    
    # advance the counter not each time add_graph button is pressed,
    # but when an actual area is selected and then add_graph is pressed
    # otherwise, figure names can be something like Figure 1, Figure 4, Figure 6 etc
    
    if len(_seq)>=1: 
        
        globals()['_Sel_' + str(min(_to_commit))].description = str(_counter+1) + ': ' + _graph_type_selector
        
        # add graph type to the list
        _specs_graphs.append(_graph_type_selector)
        
#         if _graph_title.value == '':
#             _graph_titles.append('Graph ' + str(_counter + 1))
#         else:
#             _graph_titles.append(_graph_title.value)
            
#         _graph_types.value = 'Scatter Plot' # reset element type value each time a graph is added
        
        _counter+= 1   
    
    #---------------------------
    
    # after selecting the area for a figure and adding a Figure, remove functions associated with ALL 
    # the buttons (functions for non-colored graphs will be redefined below)
    
    for i in list(np.arange(_rows*_columns)+1):
        string = '_Sel_' + str(i) + '.on_click(_Sel_' + str(i) + '_func, remove=True)'
        exec(string)
        string = '_Sel_' + str(i) + '.on_click(_show_add_graph, remove=True)'
        exec(string)
        
for i in _graph_types:
    
    globals()[i.replace(' ', '_') + '_button'].on_click(_add_graph_func)

# %%
# ========================================================================================================

def _non_colored_buttons_func(a):
    
    global _colored_buttons, _create_code
    
    #---------------------------
    
    # buttons that are currently colored
    _colored_buttons = [i for i in list(np.arange(_rows*_columns)+1) if globals()[
                         '_Sel_' + str(i)].style.button_color in _canvas_button_colors]
    
    # buttons that are not colored yet
    for i in [k for k in list(np.arange(_rows*_columns)+1) if k not in _colored_buttons]: 
                
        ls = [ # list of buttons that are eligible to be pressed, after the previous graph is made
                j for j in [
                    k for k in [
                        l for l in _modulo_dict.keys()
                        if _modulo_dict[l] <= _modulo_dict[i]
                    ] if k <= i
                ] if j not in _colored_buttons
              ]
        
        #---------------------------
        
        start = 1
        end = _columns + 1
        ls_count = []   # list of elements that fall on each row (e.g, graph covering 4, 5, 7, 8 in a 3x3 graph
                        # will result in [0, 2, 2])

        for j in range(_rows): # for each row count the number of elements that fall on it and append to ls_count

            ls_count.append(len([k for k in ls if k in range(start, end)]))

            start+= _columns
            end+= _columns
                                    
        if len(set([i for i in ls_count if i!=0]))==1: # if the selected area is symmetric
            
            non_ls = [i for i in sorted([i for i in list(np.arange(_rows*_columns)+1) if i not in ls]) if i not in _colored_buttons]

            string = 'global _Sel_' + str(i) + '_func' + '\n' + \
                     'def _Sel_' + str(i) + '_func(a):\n' + \
                     '\tglobal _to_commit' + '\n' + \
                     '\t_to_commit = ' + ''.join(str(ls)) + '\n' + \
                     '\tfor k in ' + ''.join(str(ls)) + ':' + '\n' + \
                     '\t\tglobals()["_Sel_" + str(k)].style.button_color = "' + 'darkgrey' + '"\n' + \
                     '\tfor k in ' + ''.join(str(non_ls)) + ':' + '\n' + \
                     '\t\tglobals()["_Sel_" + str(k)].style.button_color = "gainsboro"' + '\n' + \
                     '_Sel_' + str(i) + '.on_click(_Sel_' + str(i) + '_func)' + '\n' + \
                     '_Sel_' + str(i) + '.on_click(_show_add_graph)'

            exec(string)
             
        else:
            pass
        
            #                      '\t\tglobals()["_Sel_" + str(k)]' + '.on_click(_show_add_graph, remove=True)' + '\n' + \
#                      '\t\tglobals()["_Sel_" + str(k)]' + '.on_click(_show_select_area)' + '\n' + \
    
    #---------------------------
    
    # disable add_graph button once all buttons are colored

    if len(_colored_buttons) == _rows*_columns:
        
        with _graphs_top_out:
            
            clear_output(True)
            
            display(w.HBox([
                w.Label('Dashboard',
                            style = {'font_size' :'24px', 'font_weight': 'bold', 'text_color': '#32b7ec'}),
                _separator, 
                w.Label('title: ',
                            style = {'font_size' :'24px', 'font_weight': 'bold', 'text_color': 'grey'}),
                _dashboard_title, _separator,
                w.Label('color: ',
                            style = {'font_size' :'24px', 'font_weight': 'bold', 'text_color': 'grey'}),
                _dashboard_color,_separator,
                _view_code, _separator, _restart_canvas],

            layout=w.Layout(align_items='center', justify_content='center', height = '45px')))
        
        _add_graph.disabled=True
        _create_code = 'Yes'
    
    else:
        
        with _graphs_top_out:
            
            clear_output(True)
            
            display(w.HBox([
                w.Label('Select an area for a graph to continue',
                            style = {'font_size' :'20px', 'font_weight': 'bold', 'font_family' : 'Chalkduster',
                                     'text_color': '#32b7ec'}),
                _separator, _restart_canvas],
            layout=w.Layout(align_items='center', justify_content='center', height = '45px')))
        
        _create_code = 'No'
            
for i in _graph_types:
    
    globals()[i.replace(' ', '_') + '_button'].on_click(_non_colored_buttons_func)

# %%
# ========================================================================================================
        
def _create_graph_code_func(a):
    
    global _specs_elements
        
    #---------------------------
    
    if len(_seq)>=1: # only execute the below code when at least 1 button is selected
    
        # copy of dict_initial
        dict_column_span = _modulo_dict.copy()

        for i in np.arange(_rows)+1:
            dict_column_span[(i*_columns)] = _columns
        
        #---------------------------
        
        start = 1
        end = _columns + 1
        
        ls_count = []   # list of elements that fall on each row (e.g, graph covering 4, 5, 7, 8 in a 3x3 graph
                        # will result in [0, 2, 2])

        for j in range(_rows): # for each row count the number of elements that fall on it and append to ls_count

            ls_count.append(len([k for k in _to_commit if k in range(start, end)]))

            start+= _columns
            end+= _columns

        row_count = len([i for i in ls_count if i>0]) # how many rows does a figure cover
        col_count = set([i for i in ls_count if i>0]) # how many columns does a figure cover
        
        #---------------------------
        
        # make individual specs elements for plotly
        
        if len(_to_commit) == 1:

            _specs_elements[min(_to_commit)-1] = {}

        else:  

            _specs_elements[min(_to_commit)-1] = {'rowspan': row_count, 
                                                  'colspan': int(re.sub('[{}]',  '', str(col_count)))}

        _specs_elements = [None if x == '' else x for x in _specs_elements]
        
        #---------------------------
        
        # create final specs for plotly
        
        for num, i in enumerate([list(range(_rows*_columns)[i:i+_columns]) for i in range(
            0, _rows*_columns, _columns)]):
            _final_specs[num] = _specs_elements[min(i):max(i)+1]

        
        #---------------------------
        
        # determine on which row and column the graph starts
        
        row_start = []
        for num, i in enumerate([i > 0 for i in ls_count]):
                if i == True:
                    row_start.append(num)

        row_start = [i for i in row_start][0] + 1
        col_start = [val-1 for key,val in dict_column_span.items() if key == min(_to_commit)][0] + 1

        _row_col_start.append((row_start, col_start))

for i in _graph_types:
    globals()[i.replace(' ', '_') + '_button'].on_click(_create_graph_code_func)

# %%
# ========================================================================================================

def _add_graph_type_to_final_specs(a):
    
    # original _specs_graphs are not sorted correctly to be used for the final specs, they merely capture the ORDER of the added graphs, but since graphs are added row-wise in specs, _specs graphs have to be sorted correctly
    sorted_specs_graphs = sorted(list(enumerate(_row_col_start)), key=lambda x: (x[1][0], x[1][1]))
    sorted_indices = [i[0] for i in sorted_specs_graphs]
    sorted_specs_graphs = [_specs_graphs[i] for i in sorted_indices]
        
    counter = 0 # not to be mistaken with the GLOBAL counter
    
    for num, i in enumerate(_final_specs):
        for num2, i in enumerate(i):
            if isinstance(i, dict):
                _final_specs[num][num2]['type'] = sorted_specs_graphs[counter]
                counter += 1
                
for i in _graph_types:
    globals()[i.replace(' ', '_') + '_button'].on_click(_add_graph_type_to_final_specs)

# %%
# ========================================================================================================

def _copy_final_code(a):
    
    if _create_code == 'Yes':

        spec_str = \
               str(_final_specs). \
               replace('None', _green_font + 'None' + _grey_font). \
               replace('],', '], <br>' + '&nbsp'*30). \
               replace("'colspan'", _red_font + "'colspan'" + _grey_font). \
               replace("'rowspan'", _red_font + "'rowspan'" + _grey_font). \
               replace("'type'", _red_font + "'type'" + _grey_font). \
               replace("'Scatter Plot'", _red_font + "'Scatter'" + _grey_font). \
               replace("'Line Plot'", _red_font + "'Scatter'" + _grey_font). \
               replace("'Bar Plot'", _red_font + "'Bar'" + _grey_font). \
               replace("'Pie Plot'", _red_font + "'Pie'" + _grey_font). \
               replace("'Histogram'", _red_font + "'Histogram'" + _grey_font). \
               replace("'HeatMap'", _red_font + "'Heatmap'" + _grey_font). \
               replace("'Table'", _red_font + "'Table'" + _grey_font). \
               replace(': ', ': ' + _green_font). \
               replace(', ', _grey_font + ', ')
        
        # ------------------------------------------
        
        trace_code = []

        for num, i in enumerate(_specs_graphs):
            
            # ----------------
            
            _graph_number_code = \
                _green_font + '<i>' + '# GRAPH ' + str(num+1) + ': ' + _skyblue_highlight + _green_font + i + _no_highlight + '<br>'
            
            # ----------------
            
            if i  == 'Scatter Plot':
                
                _x_y_code = \
                    _grey_font + '</i>' + 'fig.add_trace(' + '<br>' + '&nbsp' * 15 + 'go.Scatter' + '(<br>' + \
                    _grey_font + '&nbsp' * 27 + 'x' + _violet_font + ' = ' + _grey_font + 'df[' + _red_font + "'x'" + _grey_font + '],' + _green_font + ' <i># or enter a list of NUMERIC values manually</i><br>' + \
                    _grey_font + '&nbsp' * 27 + 'y' + _violet_font + ' = ' + _grey_font + 'df[' + _red_font + "'y'" + _grey_font +'],' + _green_font + ' <i># or enter a list of NUMERIC values manually</i><br>' + \
                    _grey_font + '&nbsp' * 27 + 'mode' + _violet_font + ' = ' + _red_font + "'markers'" + _grey_font + ',' + '<br>' + \
                    _grey_font + '&nbsp' * 27 + 'marker_size' + _violet_font + ' = ' + _green_font + '4' + _grey_font + ',' + '<br>' + \
                    _grey_font + '&nbsp' * 27 + 'marker_color' + _violet_font + ' = ' + _red_font + "'royalblue'" + _grey_font + ',' + '<br>' + \
                    _grey_font + '&nbsp' * 27 + 'marker_symbol' + _violet_font + ' = ' + _red_font + "'circle'" + _grey_font + ',' + _green_font + ' <i># or "square", "diamond", "cross", etc.' +  '</i><br>' + \
                    _grey_font + '&nbsp' * 27 + 'marker_line_width' + _violet_font + ' = ' + _green_font + '1' + _grey_font + ',' + '<br>' + \
                    _grey_font + '&nbsp' * 27 + 'marker_line_color' + _violet_font + ' = ' + _red_font + "'grey'" + _grey_font + '),' + '<br>'
            
            
            elif i  == 'Line Plot':
                
                _x_y_code = \
                    _grey_font + '</i>' + 'fig.add_trace(' + '<br>' + '&nbsp' * 15 + 'go.Scatter' + '(<br>' + \
                    _grey_font + '&nbsp' * 27 + 'x' + _violet_font + ' = ' + _grey_font + 'df[' + _red_font + "'x'" + _grey_font + '],' + _green_font + ' <i># or enter a list of NUMERIC values manually</i><br>' + \
                    _grey_font + '&nbsp' * 27 + 'y' + _violet_font + ' = ' + _grey_font + 'df[' + _red_font + "'y'" + _grey_font +'],' + _green_font + ' <i># or enter a list of NUMERIC values manually</i><br>' + \
                    _grey_font + '&nbsp' * 27 + 'mode' + _violet_font + ' = ' + _red_font + "'lines+markers'" + _grey_font + ',' + _green_font + ' <i># or "lines" (remove marker settings in this case) </i><br>' + \
                    _grey_font + '&nbsp' * 27 + 'marker_size' + _violet_font + ' = ' + _green_font + '4' + _grey_font + ',' + '<br>' + \
                    _grey_font + '&nbsp' * 27 + 'marker_color' + _violet_font + ' = ' + _red_font + "'salmon'" + _grey_font + ',' + '<br>' + \
                    _grey_font + '&nbsp' * 27 + 'marker_symbol' + _violet_font + ' = ' + _red_font + "'circle'" + _grey_font + ',' + _green_font + ' <i># or "square", "diamond", "cross", etc.' +  '</i><br>' + \
                    _grey_font + '&nbsp' * 27 + 'marker_line_width' + _violet_font + ' = ' + _green_font + '1' + _grey_font + ',' + '<br>' + \
                    _grey_font + '&nbsp' * 27 + 'marker_line_color' + _violet_font + ' = ' + _red_font + "'grey'" + _grey_font + '),' + '<br>'
                
                
            elif i == 'Bar Plot':
                
                _x_y_code = \
                    _grey_font + '</i>' + 'fig.add_trace(' + '<br>' + '&nbsp' * 15 + 'go.Bar' + '(<br>' + ' ' * 18 + \
                    _grey_font + '&nbsp' * 22 + 'x' + _violet_font + ' = ' + _grey_font + 'df[' + _red_font + "'x'" + _grey_font + '],' + _green_font + ' <i># or enter a list of CATEGORICAL values manually</i><br>' + \
                    _grey_font + '&nbsp' * 22 + 'y' + _violet_font + ' = ' + _grey_font + 'df[' + _red_font + "'y'" + _grey_font +'],' + _green_font + ' <i># or enter a list of NUMERIC values manually</i><br>' + \
                    _grey_font + '&nbsp' * 22 + 'marker_color' + _violet_font + ' = ' + _red_font + "'teal'" + _grey_font + ',' + '<br>' + \
                    _grey_font + '&nbsp' * 22 + 'marker_line_width' + _violet_font + ' = ' + _green_font + '1' + _grey_font + ',' + '<br>' + \
                    _grey_font + '&nbsp' * 22 + 'marker_line_color' + _violet_font + ' = ' + _red_font + "'grey'" + _grey_font + '),' + '<br>'
            
            
            elif i == 'Pie Plot':
                
                _x_y_code = \
                    _grey_font + '</i>' + 'fig.add_trace(' + '<br>' + '&nbsp' * 15 + 'go.Pie' + '(<br>' + ' ' * 18 + \
                    _grey_font + '&nbsp' * 22 + 'labels' + _violet_font + ' = ' + _grey_font + 'df[' + _red_font + "'x'" + _grey_font + '],' + _green_font + ' <i># or enter a list of CATEGORICAL values manually</i><br>' + \
                    _grey_font + '&nbsp' * 22 + 'values' + _violet_font + ' = ' + _grey_font + 'df[' + _red_font + "'y'" + _grey_font +'],' + _green_font + ' <i># or enter a list of NUMERIC values manually</i><br>' + \
                    _grey_font + '&nbsp' * 22 + 'marker_colors' + _violet_font + ' = ' + _grey_font + '[_, _, _ ect]), ' + _green_font + ' <i># enter a list of as many colors as there are categories for "x"</i><br>'
            
            
            elif i == 'Table':
                
                _x_y_code = \
                    _grey_font + '</i>' + 'fig.add_trace(' + '<br>' + '&nbsp' * 15 + 'go.Table' + '(<br>' + ' ' * 18 + \
                    '&nbsp' * 24 + 'header ' + _violet_font + ' = ' + _grey_font + \
                    _green_font + 'dict' + _grey_font +  '(values' + _violet_font + ' = ' + _green_font + 'list' + _grey_font  + '(df.columns),' + _green_font + '<i> # or enter a list of COLUMN NAMES manually</i><br>' + \
                    _grey_font + '&nbsp' * 39 + 'line_color' + _violet_font + ' = ' + _red_font + "'black'" + _grey_font + ',' + '<br>' + \
                    _grey_font + '&nbsp' * 39 + 'fill_color' + _violet_font + ' = ' + _red_font + "'darkslategrey'" + _grey_font + ',' + '<br>' + \
                    _grey_font + '&nbsp' * 39 + 'height' + _violet_font + ' = ' + _green_font + '25' + _grey_font + ',' + '<br>' + \
                    _grey_font + '&nbsp' * 39 + 'align' + _violet_font + ' = ' + _red_font + "'center'" + _grey_font + ',' + '<br>' + \
                    _grey_font + '&nbsp' * 39 + 'font_family' + _violet_font + ' = ' + _red_font + "'Chalkduster'" + _grey_font + ',' + '<br>' + \
                    _grey_font + '&nbsp' * 39 + 'font_color' + _violet_font + ' = ' + _red_font + "'white'" + _grey_font + ',' + '<br>' + \
                    _grey_font + '&nbsp' * 39 + 'font_size' + _violet_font + ' = ' + _green_font + '14' + _grey_font + '),' + '<br><br>' + \
                    '&nbsp' * 24 + 'cells ' + _violet_font + ' = ' + _grey_font + \
                    _green_font + 'dict' + _grey_font +  '(values' + _violet_font + ' = ' + _grey_font + '[df[i][:' + _green_font +  '10' + _grey_font + '] ' + _green_font + 'for ' + _grey_font +  'i ' + _green_font +  'in ' + _grey_font  + 'df.columns],' + _green_font + '<i> # or enter a list of TABLE VALUES manually</i><br>' + \
                    _grey_font + '&nbsp' * 37 + 'line_color' + _violet_font + ' = ' + _red_font + "'grey'" + _grey_font + ',' + '<br>' + \
                    _grey_font + '&nbsp' * 37 + 'fill_color' + _violet_font + ' = ' + _red_font + "'linen'" + _grey_font + ',' + '<br>' + \
                    _grey_font + '&nbsp' * 37 + 'height' + _violet_font + ' = ' + _green_font + '20' + _grey_font + ',' + '<br>' + \
                    _grey_font + '&nbsp' * 37 + 'font_family' + _violet_font + ' = ' + _red_font + "'Arial'" + _grey_font + ',' + '<br>' + \
                    _grey_font + '&nbsp' * 37 + 'align' + _violet_font + ' = ' + _red_font + "'center'" + _grey_font + ',' + '<br>' + \
                    _grey_font + '&nbsp' * 37 + 'font_color' + _violet_font + ' = ' + _red_font + "'darkslategrey'" + _grey_font + ',' + '<br>' + \
                    _grey_font + '&nbsp' * 37 + 'font_size' + _violet_font + ' = ' + _green_font + '12' + _grey_font + ')),' + '<br>'
            
            # ----------------
            
            _row_col_code = \
                _grey_font + '&nbsp' * 15 + 'row ' + _violet_font + '= ' + _green_font + str(_row_col_start[num][0]) + \
                _grey_font + ', col ' + _violet_font + '= ' + _green_font + str(_row_col_start[num][1]) + _grey_font + ')<br><br><br>'
            
            # ----------------
            
            if i not in ['Pie Plot', 'Table']:
                _axes_code = \
                    _grey_font + 'fig.update_xaxes(title_text' + _violet_font + ' = ' + _red_font + \
                    "'X-axis'" + _grey_font + ', row' + _violet_font + ' = ' + _green_font + str(_row_col_start[num][0]) + \
                    _grey_font + ', col' + _violet_font + ' = ' + _green_font + str(_row_col_start[num][1]) + ')<br>' + \
                    _grey_font + 'fig.update_yaxes(title_text' + _violet_font + ' = ' + _red_font + \
                    "'Y-axis'" + _grey_font + ', row' + _violet_font + ' = ' + _green_font + str(_row_col_start[num][0]) + \
                    _grey_font + ', col' + _violet_font + ' = ' + _green_font + str(_row_col_start[num][1]) + ')<br><br><br>'
               
            else:
                _axes_code = ''

            # ----------------
            
            trace_code.append('</i>' + 
                              _graph_number_code + 
                              _x_y_code + 
                              _row_col_code + 
                              _axes_code + 
                              _green_font + '<i># ============================================================================ <br><br>')
        
        _trace_code = _grey_font + '</i>' + ''.join(trace_code)
        
        # ================================================================================================
        
        _import_code = \
            _green_font + 'import ' + _grey_font + 'plotly.graph_objects ' + _green_font + 'as ' + _grey_font + 'go' + '<br>' + \
            _green_font + 'from ' + _grey_font + 'plotly.subplots ' + _green_font + 'import ' + _grey_font + 'make_subplots<br>' + \
            _green_font + 'import ' + _grey_font + 'ipywidgets ' + _green_font + 'as ' + _grey_font + 'w' + '<br><br>'

        
        _make_subplots_code = \
            _grey_font + '</i>fig' + _violet_font +  ' = ' + \
            _grey_font + 'make_subplots(' + _green_font + '<i># ' + _bisque_highlight + _green_font + 'Create SUBPLOTS</i>' + _no_highlight + '<br>' + '&nbsp' * 22 + \
            _grey_font + 'rows'  + _violet_font + ' = ' + _green_font + str(_rows) + _grey_font + ', <br>' + '&nbsp' * 22 + \
            _grey_font + 'cols ' + _violet_font + ' = ' + _green_font + str(_columns) + _grey_font +', <br>' + '&nbsp' * 22 +  \
            _grey_font + 'horizontal_spacing'  + _violet_font + ' = ' + _green_font + '0.1' + _grey_font + ', ' + _green_font + ' <i># Add space between graphs horizontally  </i>' + '<br>' + '&nbsp' * 22 + \
            _grey_font + 'vertical_spacing'  + _violet_font + ' = ' + _green_font + '0.1' + _grey_font + ', ' + _green_font + ' <i># Add space between graphs vertically  </i>' + '<br>' + '&nbsp' * 22 + \
            _grey_font + 'specs ' + _violet_font + ' = ' + _grey_font + spec_str + ')<br><br><br>'
        
        
        _title_code = \
            _grey_font + 'fig.update_layout(' + _green_font + '<i>' + '# Update ' + _bisque_highlight + _green_font + 'TITLE</i>' + _no_highlight + '<br>' + \
            _grey_font + '&nbsp' * 19 + 'title' + _violet_font + ' = ' + _red_font + "'" + _dashboard_title.value + "'" + _grey_font + ', ' + '<br>' + \
            _grey_font + '&nbsp' * 19 + 'title_x' + _violet_font + ' = ' + _green_font + ' 0.5' + _grey_font + ', ' + _green_font + '<i># Adjust the position of the title horizontally (0 to 1)' + '<br>' + \
            _grey_font + '&nbsp' * 19 + '</i>title_y' + _violet_font + ' = ' + _green_font + ' 0.95' + _grey_font + ', ' + _green_font + '<i># Adjust the position of the title vertically (0 to 1)' + '<br>' + \
            _grey_font + '&nbsp' * 19 + '</i>title_font_family' + _violet_font + ' = ' + _red_font + "'" + 'Chalkduster' + "'" + _grey_font + ', ' +_green_font  + "<i> # or 'Arial', 'Times', 'Comic SANS MS' etc"  + '<br>' + \
            _grey_font + '&nbsp' * 19 + '</i>title_font_size' + _violet_font + ' = ' + _green_font + '24' + _grey_font + ', ' + '<br>' + \
            _grey_font + '&nbsp' * 19 + '</i>title_font_color' + _violet_font + ' = ' + _red_font + "'" + 'teal' + "'" + _grey_font + ')'  + '<br><br><br>'
        
        
        _axes_code = \
            _grey_font + 'fig.update_layout(' + _green_font + '<i>' + '# Update ' + _bisque_highlight + _green_font + 'AXES</i>' + _no_highlight + '<br>' + \
            _grey_font + '&nbsp' * 19 + 'font_family' + _violet_font + ' = ' + _red_font + "'" + 'Chalkduster' + "'" + _grey_font + ', ' + '<br>' + \
            _grey_font + '&nbsp' * 19 + 'font_size' + _violet_font + ' = ' + _green_font + '12' + _grey_font + ', '  + '<br>' + \
            _grey_font + '&nbsp' * 19 + 'font_color' + _violet_font + ' = ' + _red_font + "'" + 'grey' + "'" + _grey_font + ')'  + '<br><br><br>'
        
        
        _background_color_code = \
            _grey_font + 'fig.update_layout(' + _green_font + '<i># Update ' + _bisque_highlight + _green_font + 'BACKGROUND COLORS</i>' + _no_highlight + '<br>' + \
            _grey_font + '&nbsp' * 19 + 'paper_bgcolor' + _violet_font + ' = ' + _red_font + "'" + _dashboard_color.value + "'" + _grey_font + ', ' +'<br>' + \
            _grey_font + '&nbsp' * 19 + 'plot_bgcolor' + _violet_font + ' = ' + _red_font + "'" + _dashboard_color.value + "'" + _grey_font + ')'  + '<br><br><br>'
        
        
        _show_legend_code = \
            _grey_font + 'fig.update_layout(' + _green_font + '<i># Show/hide ' + _bisque_highlight + _green_font + 'LEGEND</i>' + _no_highlight + '<br>' + \
            _red_font + '&nbsp' * 19 + "'showlegend'" + _violet_font + ' = ' + _green_font + 'False' + _grey_font + ')' + '<br><br><br>'
        
        
        _dashboard_dimensions_code = \
            _grey_font + 'fig.update_layout(' + _green_font + '<i># Dashboard ' + _bisque_highlight + _green_font + 'WIDTH/HEIGHT</i>' + _no_highlight + '<br>' + \
            _grey_font + '&nbsp' * 19 + 'width' + _violet_font + ' = ' + _green_font + '975' + _grey_font + ',' + '<br>' + \
            _grey_font + '&nbsp' * 19 + 'height' + _violet_font + ' = ' + _green_font + '600' + _grey_font + ')' + '<br><br><br>'
        
        # ------------------------------------------
        
        with _graphs_bottom_out:
            clear_output(True)
            display(w.HBox([w.Output(layout=w.Layout(width = '25px')),
                            w.Box([w.HTML(_main_font_graphessor + '<br>' + \
                                          _import_code + \
                                          _green_font + '<i># ==========================================================================<br>' + \
                                          _bisque_highlight + _green_font + '<i>#' + '&nbsp'*30 + 'GLOBAL DASHBOARD SETTINGS' + '&nbsp'*31 + '<br></i>' + _no_highlight + \
                                          _green_font + '<i># ==========================================================================<br><br></i>' + \
                                          _make_subplots_code + \
                                          _title_code + \
                                          _axes_code + \
                                          _background_color_code + \
                                          _show_legend_code + \
                                          _dashboard_dimensions_code + \
                                          _green_font + '<i># =========================================================================<br>' + \
                                          _skyblue_highlight + _green_font + '<i>#' + '&nbsp'*30 + 'INDIVIDUAL GRAPH SETTINGS' + '&nbsp'*31 + '<br></i>' + _no_highlight + \
                                          _green_font + '<i># =========================================================================<br><br></i>' + \
                                          _trace_code)],
                                                                      layout=w.Layout(height = '600px', 
                                                                                      width = '100%', 
                                                                                      overflow='auto'))]))

_view_code.on_click(_copy_final_code)

# %%
display(_dashboard_out)
